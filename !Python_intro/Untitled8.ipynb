# %%
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv("wages_hours.csv")
data.head()
# Out:
#   HRS     RATE    ERSP    ERNO    NEIN    ASSET   AGE     DEP     RACE    SCHOOL
# 0  2157    2.905   1121    291     380     7250  ...
# 1  2174    2.970   1128    301     398     7744  ...
# 2  2062    2.350   1214    326     185     3068  ...
# 3  2111    2.511   1203    49      117     1632  ...
# 4  2134    2.791   1013    594     730     12710 ...

# %%
data = pd.read_csv("wages_hours.csv", sep = "    ")
data.head()
# Out:
# C:\Users\natha\anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#     HRS          RATE ERSP  ERNO           NEIN   ASSET   AGE           DEP  \
# 0  2157  2.905   1121  291   380           7250          38.5  2.340   32.1
# 1  2174  2.970   1128  301   398           7744          39.3  2.335   31.2
# 2  2062  2.350   1214  326   185           3068          40.1     2.851   *
# 3  2111  2.511   1203   49   117           1632          22.4  1.159   27.5
# 4  2134  2.791   1013  594   730   12710   57.7  1.229   32.5           8.8
#
#     RACE  SCHOOL
# 0   10.5     NaN
# 1   10.5     NaN
# 2    8.9     NaN
# 3   11.5     NaN
# 4    NaN     NaN

# %%
data
# Out:
#    HRS     RATE    ERSP    ERNO    NEIN    ASSET   AGE     DEP     RACE    SCHOOL
# 0   2157    2.905   1121    291     380     7250  ...
# 1   2174    2.970   1128    301     398     7744  ...
# 2   2062    2.350   1214    326     185     3068  ...
# 3   2111    2.511   1203    49      117     1632  ...
# 4   2134    2.791   1013    594     730     12710 ...
# 5   2185    3.040   1135    287     382     7706  ...
# 6   2210    3.222   1100    295     474     9338  ...
# 7   2105    2.493   1180    310     255     4730  ...
# 8   2267    2.838   1298    252     431     8317  ...
# 9   2205    2.356   885     264     373     6789  ...
# 10  2121    2.922   1251    328     312     5907  ...
# 11  2109    2.499   1207    347     271     5069  ...
# 12  2108    2.796   1036    300     259     4614  ...
# 13  2047    2.453   1213    297     139     1987  ...
# 14  2174    3.582   1141    414     498     10239 ...
# 15  2067    2.909   1805    290     239     4439  ...
# ...
